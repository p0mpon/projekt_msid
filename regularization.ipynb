# %% [markdown]
# ## 3. L1 and L2 regularization
# Comparing:
# - Linear regression with Lasso and Ridge
# - Linear regression using closed form solution with and without regularization
# - Linear regression using gradient descent with and without regularization

# %%
import pandas as pd

data = pd.read_csv('data/StudentPerformanceFactors.csv')

X = data.drop("Exam_Score", axis=1)
Y = data['Exam_Score']

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.75)

num_cols = X.select_dtypes(include=['int64', 'float64']).columns
cat_cols = X.select_dtypes(include=['object', 'category']).columns

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

from sklearn.preprocessing import OneHotEncoder

cat_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer([
    ('num', num_pipeline, num_cols),
    ('cat', cat_pipeline, cat_cols)
])

# %% [markdown]
# #### Lasso and Ridge

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso, Ridge

L1 = Lasso()
L2 = Ridge()
sklearn_LR = LinearRegression()

sklearn_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', sklearn_LR)
])

L1_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', L1)
])

L2_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', L2)
])

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np

L1_param_grid = {
    'regressor__alpha': np.logspace(-5, -1, 9)
}

L2_param_grid = {
    'regressor__alpha': np.linspace(1, 10, 10)
}

l1_grid = GridSearchCV(L1_pipeline, L1_param_grid, cv=5, scoring='r2', n_jobs=-1)
l1_grid.fit(X_train, Y_train)

l2_grid = GridSearchCV(L2_pipeline, L2_param_grid, cv=5, scoring='r2', n_jobs=-1)
l2_grid.fit(X_train, Y_train)

sklearn_pipeline.fit(X_train, Y_train)

print("Lasso Best Params:", l1_grid.best_params_)
print("Ridge Best Params:", l2_grid.best_params_)

y_pred_l1 = l1_grid.predict(X_test)
y_pred_l2 = l2_grid.predict(X_test)
y_pred_skl = sklearn_pipeline.predict(X_test)
# Out:
# Lasso Best Params: {'regressor__alpha': np.float64(0.001)}
# Ridge Best Params: {'regressor__alpha': np.float64(9.0)}

# %% [markdown]
# #### Evaluating the models

# %%
model_names = ['Lasso (L1)', 'Ridge (L2)', 'Linear Regression']
models = [l1_grid, l2_grid, sklearn_pipeline]
metrics = ['R² (train)', 'R² (test)']

results = {
    name: [
        model.score(X_train, Y_train),
        model.score(X_test, Y_test)
    ]
    for (name, model) in zip(model_names, models) 
}

df_compare = pd.DataFrame(results, index=metrics).T.round(6)

display(df_compare)
# Out:
#                    R² (train)  R² (test)
# Lasso (L1)           0.736555   0.698352
# Ridge (L2)           0.736553   0.698365
# Linear Regression    0.736563   0.698338

# %%
from src.linear_regression.model_evaluation import metrics_table

df_metrics = metrics_table(Y_test,
                           [y_pred_l1, y_pred_l2, y_pred_skl],
                           ['Lasso (L1)', 'Ridge (L2)', 'Linear Regression'])

display(df_metrics)
# Out:
#                          R²       MSE      RMSE       MAE
# Lasso (L1)         0.698352  4.665759  2.160037  0.510651
# Ridge (L2)         0.698365  4.665566  2.159992  0.510828
# Linear Regression  0.698338  4.665985  2.160089  0.510609

# %% [markdown]
# #### Comparing weights

# %%
from src.linear_regression.model_evaluation import weights_table

weights_df = weights_table(data, X,
                           [l1_grid.best_estimator_.named_steps['regressor'],
                            l2_grid.best_estimator_.named_steps['regressor'],
                            sklearn_LR],
                           ['Lasso',
                            'Ridge',
                            'Linear Regression'])

display(weights_df)
# Out:
# <style type="text/css">
# #T_73271 th {
#   text-align: left;
# }
# #T_73271_row0_col0, #T_73271_row0_col1, #T_73271_row0_col2, #T_73271_row0_col3, #T_73271_row1_col0, #T_73271_row1_col1, #T_73271_row1_col2, #T_73271_row1_col3, #T_73271_row2_col0, #T_73271_row2_col1, #T_73271_row2_col2, #T_73271_row2_col3, #T_73271_row3_col0, #T_73271_row3_col1, #T_73271_row3_col2, #T_73271_row3_col3, #T_73271_row4_col0, #T_73271_row4_col1, #T_73271_row4_col2, #T_73271_row4_col3, #T_73271_row5_col0, #T_73271_row5_col1, #T_73271_row5_col2, #T_73271_row5_col3, #T_73271_row6_col0, #T_73271_row6_col1, #T_73271_row6_col2, #T_73271_row6_col3, #T_73271_row7_col0, #T_73271_row7_col1, #T_73271_row7_col2, #T_73271_row7_col3, #T_73271_row8_col0, #T_73271_row8_col1, #T_73271_row8_col2, #T_73271_row8_col3, #T_73271_row9_col0, #T_73271_row9_col1, #T_73271_row9_col2, #T_73271_row9_col3, #T_73271_row10_col0, #T_73271_row10_col1, #T_73271_row10_col2, #T_73271_row10_col3, #T_73271_row11_col0, #T_73271_row11_col1, #T_73271_row11_col2, #T_73271_row11_col3, #T_73271_row12_col0, #T_73271_row12_col1, #T_73271_row12_col2, #T_73271_row12_col3, #T_73271_row13_col0, #T_73271_row13_col1, #T_73271_row13_col2, #T_73271_row13_col3, #T_73271_row14_col0, #T_73271_row14_col1, #T_73271_row14_col2, #T_73271_row14_col3, #T_73271_row15_col0, #T_73271_row15_col1, #T_73271_row15_col2, #T_73271_row15_col3, #T_73271_row16_col0, #T_73271_row16_col1, #T_73271_row16_col2, #T_73271_row16_col3, #T_73271_row17_col0, #T_73271_row17_col1, #T_73271_row17_col2, #T_73271_row17_col3, #T_73271_row18_col0, #T_73271_row18_col1, #T_73271_row18_col2, #T_73271_row18_col3, #T_73271_row19_col0, #T_73271_row19_col1, #T_73271_row19_col2, #T_73271_row19_col3, #T_73271_row20_col0, #T_73271_row20_col1, #T_73271_row20_col2, #T_73271_row20_col3, #T_73271_row21_col0, #T_73271_row21_col1, #T_73271_row21_col2, #T_73271_row21_col3, #T_73271_row22_col0, #T_73271_row22_col1, #T_73271_row22_col2, #T_73271_row22_col3, #T_73271_row23_col0, #T_73271_row23_col1, #T_73271_row23_col2, #T_73271_row23_col3, #T_73271_row24_col0, #T_73271_row24_col1, #T_73271_row24_col2, #T_73271_row24_col3, #T_73271_row25_col0, #T_73271_row25_col1, #T_73271_row25_col2, #T_73271_row25_col3, #T_73271_row26_col0, #T_73271_row26_col1, #T_73271_row26_col2, #T_73271_row26_col3, #T_73271_row27_col0, #T_73271_row27_col1, #T_73271_row27_col2, #T_73271_row27_col3, #T_73271_row28_col0, #T_73271_row28_col1, #T_73271_row28_col2, #T_73271_row28_col3, #T_73271_row29_col0, #T_73271_row29_col1, #T_73271_row29_col2, #T_73271_row29_col3, #T_73271_row30_col0, #T_73271_row30_col1, #T_73271_row30_col2, #T_73271_row30_col3, #T_73271_row31_col0, #T_73271_row31_col1, #T_73271_row31_col2, #T_73271_row31_col3, #T_73271_row32_col0, #T_73271_row32_col1, #T_73271_row32_col2, #T_73271_row32_col3, #T_73271_row33_col0, #T_73271_row33_col1, #T_73271_row33_col2, #T_73271_row33_col3, #T_73271_row34_col0, #T_73271_row34_col1, #T_73271_row34_col2, #T_73271_row34_col3, #T_73271_row35_col0, #T_73271_row35_col1, #T_73271_row35_col2, #T_73271_row35_col3, #T_73271_row36_col0, #T_73271_row36_col1, #T_73271_row36_col2, #T_73271_row36_col3, #T_73271_row37_col0, #T_73271_row37_col1, #T_73271_row37_col2, #T_73271_row37_col3, #T_73271_row38_col0, #T_73271_row38_col1, #T_73271_row38_col2, #T_73271_row38_col3, #T_73271_row39_col0, #T_73271_row39_col1, #T_73271_row39_col2, #T_73271_row39_col3, #T_73271_row40_col0, #T_73271_row40_col1, #T_73271_row40_col2, #T_73271_row40_col3 {
#   text-align: left;
#   white-space: normal;
#   min-width: 200px;
# }
# </style>
# <table id="T_73271">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73271_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_73271_level0_col1" class="col_heading level0 col1" >Lasso</th>
#       <th id="T_73271_level0_col2" class="col_heading level0 col2" >Ridge</th>
#       <th id="T_73271_level0_col3" class="col_heading level0 col3" >Linear Regression</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73271_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73271_row0_col0" class="data row0 col0" >Hours_Studied</td>
#       <td id="T_73271_row0_col1" class="data row0 col1" >1.772080</td>
#       <td id="T_73271_row0_col2" class="data row0 col2" >1.769784</td>
#       <td id="T_73271_row0_col3" class="data row0 col3" >1.773200</td>
#     </tr>
#     <tr>
#       <th id="T_73271_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_73271_row1_col0" class="data row1 col0" >Attendance</td>
#       <td id="T_73271_row1_col1" class="data row1 col1" >2.278392</td>
#       <td id="T_73271_row1_col2" class="data row1 col2" >2.275209</td>
#       <td id="T_73271_row1_col3" class="data row1 col3" >2.279449</td>
#     </tr>
#     <tr>
#       <th id="T_73271_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_73271_row2_col0" class="data row2 col0" >Sleep_Hours</td>
#       <td id="T_73271_row2_col1" class="data row2 col1" >-0.001198</td>
#       <td id="T_73271_row2_col2" class="data row2 col2" >-0.002314</td>
#       <td id="T_73271_row2_col3" class="data row2 col3" >-0.002066</td>
#     </tr>
#     <tr>
#       <th id="T_73271_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_73271_row3_col0" class="data row3 col0" >Previous_Scores</td>
#       <td id="T_73271_row3_col1" class="data row3 col1" >0.686444</td>
#       <td id="T_73271_row3_col2" class="data row3 col2" >0.686243</td>
#       <td id="T_73271_row3_col3" class="data row3 col3" >0.687438</td>
#     </tr>
#     <tr>
#       <th id="T_73271_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_73271_row4_col0" class="data row4 col0" >Tutoring_Sessions</td>
#       <td id="T_73271_row4_col1" class="data row4 col1" >0.628561</td>
#       <td id="T_73271_row4_col2" class="data row4 col2" >0.628423</td>
#       <td id="T_73271_row4_col3" class="data row4 col3" >0.629571</td>
#     </tr>
#     <tr>
#       <th id="T_73271_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_73271_row5_col0" class="data row5 col0" >Physical_Activity</td>
#       <td id="T_73271_row5_col1" class="data row5 col1" >0.181699</td>
#       <td id="T_73271_row5_col2" class="data row5 col2" >0.182305</td>
#       <td id="T_73271_row5_col3" class="data row5 col3" >0.183075</td>
#     </tr>
#     <tr>
#       <th id="T_73271_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_73271_row6_col0" class="data row6 col0" >Parental_Involvement - Low</td>
#       <td id="T_73271_row6_col1" class="data row6 col1" >1.074642</td>
#       <td id="T_73271_row6_col2" class="data row6 col2" >1.015001</td>
#       <td id="T_73271_row6_col3" class="data row6 col3" >1.022632</td>
#     </tr>
#     <tr>
#       <th id="T_73271_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_73271_row7_col0" class="data row7 col0" >Parental_Involvement - Medium</td>
#       <td id="T_73271_row7_col1" class="data row7 col1" >-0.905978</td>
#       <td id="T_73271_row7_col2" class="data row7 col2" >-0.958564</td>
#       <td id="T_73271_row7_col3" class="data row7 col3" >-0.966809</td>
#     </tr>
#     <tr>
#       <th id="T_73271_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_73271_row8_col0" class="data row8 col0" >Parental_Involvement - High</td>
#       <td id="T_73271_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_73271_row8_col2" class="data row8 col2" >-0.056436</td>
#       <td id="T_73271_row8_col3" class="data row8 col3" >-0.055823</td>
#     </tr>
#     <tr>
#       <th id="T_73271_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_73271_row9_col0" class="data row9 col0" >Access_to_Resources - High</td>
#       <td id="T_73271_row9_col1" class="data row9 col1" >1.038871</td>
#       <td id="T_73271_row9_col2" class="data row9 col2" >1.044060</td>
#       <td id="T_73271_row9_col3" class="data row9 col3" >1.051774</td>
#     </tr>
#     <tr>
#       <th id="T_73271_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_73271_row10_co

# %% [markdown]
# ### Adding regularization to own models

# %%
from src.linear_regression.models import LinearRegressionClosedForm, LinearRegressionGradientDescent

closed_form_LR = LinearRegressionClosedForm()

closed_form_LR_L2 = LinearRegressionClosedForm(regularization=True, alpha=0.1)

gradient_descent_LR = LinearRegressionGradientDescent()

gradient_descent_LR_L1 = LinearRegressionGradientDescent(regularization='l1', alpha=0.005)
gradient_descent_LR_L2 = LinearRegressionGradientDescent(regularization='l2', alpha=0.0005)
gradient_descent_LR_en = LinearRegressionGradientDescent(regularization='elasticnet', alpha=0.001)

closed_form_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', closed_form_LR)
])

cf_LR_L2_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', closed_form_LR_L2)
])

gradient_descent_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', gradient_descent_LR)
])

gd_LR_L1_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', gradient_descent_LR_L1)
])

gd_LR_L2_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', gradient_descent_LR_L2)
])

gd_LR_en_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', gradient_descent_LR_en)
])

# %%
closed_form_pipeline.fit(X_train, Y_train)
cf_LR_L2_pipeline.fit(X_train, Y_train)

gradient_descent_pipeline.fit(X_train, Y_train)
gd_LR_L1_pipeline.fit(X_train, Y_train)
gd_LR_L2_pipeline.fit(X_train, Y_train)
gd_LR_en_pipeline.fit(X_train, Y_train)

y_pred_cf = closed_form_pipeline.predict(X_test)
y_pred_cf_L2 = cf_LR_L2_pipeline.predict(X_test)

y_pred_gd = gradient_descent_pipeline.predict(X_test)
y_pred_gd_l1 = gd_LR_L1_pipeline.predict(X_test)
y_pred_gd_l2 = gd_LR_L2_pipeline.predict(X_test)
y_pred_gd_en = gd_LR_en_pipeline.predict(X_test)

# %% [markdown]
# #### Evaluation

# %%
from src.linear_regression.model_evaluation import metrics_table, weights_table

df_metrics_reg = metrics_table(Y_test,
                           [y_pred_cf_L2, y_pred_cf, y_pred_gd_l1, y_pred_gd_l2, y_pred_gd_en, y_pred_gd],
                           ['Closed Form with L2',
                            'Closed for without regularization',
                            'Gradient Descent with L1',
                            'Gradient Descent with L2',
                            'Gradient Descent with both (0.5 ratio)',
                            'Gradient Descent without regularization'])

display(df_metrics_reg)
# Out:
#                                                R²       MSE      RMSE  \
# Closed Form with L2                      0.726141  4.690487  2.165753
# Closed for without regularization        0.726145  4.690414  2.165736
# Gradient Descent with L1                 0.726184  4.689744  2.165582
# Gradient Descent with L2                 0.725785  4.696571  2.167157
# Gradient Descent with both (0.5 ratio)   0.726062  4.691839  2.166065
# Gradient Descent without regularization  0.725749  4.697191  2.167300
#
#                                               MAE
# Closed Form with L2                      0.516443
# Closed for without regularization        0.516526
# Gradient Descent with L1                 0.518720
# Gradient Descent with L2                 0.518544
# Gradient Descent with both (0.5 ratio)   0.512817
# Gradient Descent without regularization  0.513474

# %% [markdown]
# #### Gradient descent weights

# %%
models = [gradient_descent_LR_L1, gradient_descent_LR_L2, gradient_descent_LR_en, gradient_descent_LR]
model_names = ['GD with L1', 'GD with L2', 'GD with both', 'GD without regularization']

df_weights_reg = weights_table(data, X, models, model_names)

display(df_weights_reg)
# Out:
# <style type="text/css">
# #T_54667 th {
#   text-align: left;
# }
# #T_54667_row0_col0, #T_54667_row0_col1, #T_54667_row0_col2, #T_54667_row0_col3, #T_54667_row0_col4, #T_54667_row1_col0, #T_54667_row1_col1, #T_54667_row1_col2, #T_54667_row1_col3, #T_54667_row1_col4, #T_54667_row2_col0, #T_54667_row2_col1, #T_54667_row2_col2, #T_54667_row2_col3, #T_54667_row2_col4, #T_54667_row3_col0, #T_54667_row3_col1, #T_54667_row3_col2, #T_54667_row3_col3, #T_54667_row3_col4, #T_54667_row4_col0, #T_54667_row4_col1, #T_54667_row4_col2, #T_54667_row4_col3, #T_54667_row4_col4, #T_54667_row5_col0, #T_54667_row5_col1, #T_54667_row5_col2, #T_54667_row5_col3, #T_54667_row5_col4, #T_54667_row6_col0, #T_54667_row6_col1, #T_54667_row6_col2, #T_54667_row6_col3, #T_54667_row6_col4, #T_54667_row7_col0, #T_54667_row7_col1, #T_54667_row7_col2, #T_54667_row7_col3, #T_54667_row7_col4, #T_54667_row8_col0, #T_54667_row8_col1, #T_54667_row8_col2, #T_54667_row8_col3, #T_54667_row8_col4, #T_54667_row9_col0, #T_54667_row9_col1, #T_54667_row9_col2, #T_54667_row9_col3, #T_54667_row9_col4, #T_54667_row10_col0, #T_54667_row10_col1, #T_54667_row10_col2, #T_54667_row10_col3, #T_54667_row10_col4, #T_54667_row11_col0, #T_54667_row11_col1, #T_54667_row11_col2, #T_54667_row11_col3, #T_54667_row11_col4, #T_54667_row12_col0, #T_54667_row12_col1, #T_54667_row12_col2, #T_54667_row12_col3, #T_54667_row12_col4, #T_54667_row13_col0, #T_54667_row13_col1, #T_54667_row13_col2, #T_54667_row13_col3, #T_54667_row13_col4, #T_54667_row14_col0, #T_54667_row14_col1, #T_54667_row14_col2, #T_54667_row14_col3, #T_54667_row14_col4, #T_54667_row15_col0, #T_54667_row15_col1, #T_54667_row15_col2, #T_54667_row15_col3, #T_54667_row15_col4, #T_54667_row16_col0, #T_54667_row16_col1, #T_54667_row16_col2, #T_54667_row16_col3, #T_54667_row16_col4, #T_54667_row17_col0, #T_54667_row17_col1, #T_54667_row17_col2, #T_54667_row17_col3, #T_54667_row17_col4, #T_54667_row18_col0, #T_54667_row18_col1, #T_54667_row18_col2, #T_54667_row18_col3, #T_54667_row18_col4, #T_54667_row19_col0, #T_54667_row19_col1, #T_54667_row19_col2, #T_54667_row19_col3, #T_54667_row19_col4, #T_54667_row20_col0, #T_54667_row20_col1, #T_54667_row20_col2, #T_54667_row20_col3, #T_54667_row20_col4, #T_54667_row21_col0, #T_54667_row21_col1, #T_54667_row21_col2, #T_54667_row21_col3, #T_54667_row21_col4, #T_54667_row22_col0, #T_54667_row22_col1, #T_54667_row22_col2, #T_54667_row22_col3, #T_54667_row22_col4, #T_54667_row23_col0, #T_54667_row23_col1, #T_54667_row23_col2, #T_54667_row23_col3, #T_54667_row23_col4, #T_54667_row24_col0, #T_54667_row24_col1, #T_54667_row24_col2, #T_54667_row24_col3, #T_54667_row24_col4, #T_54667_row25_col0, #T_54667_row25_col1, #T_54667_row25_col2, #T_54667_row25_col3, #T_54667_row25_col4, #T_54667_row26_col0, #T_54667_row26_col1, #T_54667_row26_col2, #T_54667_row26_col3, #T_54667_row26_col4, #T_54667_row27_col0, #T_54667_row27_col1, #T_54667_row27_col2, #T_54667_row27_col3, #T_54667_row27_col4, #T_54667_row28_col0, #T_54667_row28_col1, #T_54667_row28_col2, #T_54667_row28_col3, #T_54667_row28_col4, #T_54667_row29_col0, #T_54667_row29_col1, #T_54667_row29_col2, #T_54667_row29_col3, #T_54667_row29_col4, #T_54667_row30_col0, #T_54667_row30_col1, #T_54667_row30_col2, #T_54667_row30_col3, #T_54667_row30_col4, #T_54667_row31_col0, #T_54667_row31_col1, #T_54667_row31_col2, #T_54667_row31_col3, #T_54667_row31_col4, #T_54667_row32_col0, #T_54667_row32_col1, #T_54667_row32_col2, #T_54667_row32_col3, #T_54667_row32_col4, #T_54667_row33_col0, #T_54667_row33_col1, #T_54667_row33_col2, #T_54667_row33_col3, #T_54667_row33_col4, #T_54667_row34_col0, #T_54667_row34_col1, #T_54667_row34_col2, #T_54667_row34_col3, #T_54667_row34_col4, #T_54667_row35_col0, #T_54667_row35_col1, #T_54667_row35_col2, #T_54667_row35_col3, #T_54667_row35_col4, #T_54667_row36_col0, #T_54667_row36_col1, #T_54667_row36_col2, #T_54667_row36_col3, #T_54667_row36_col4, #T_54667_row37_col0, #T_54667_row37_col1, #T_54667_row37_col2, #T_54667_row37_col3, #T_54667_row37_col4, #T_54667_row38_col0, #T_54667_row38_col1, #T_54667_row38_col ...
#   text-align: left;
#   white-space: normal;
#   min-width: 200px;
# }
# </style>
# <table id="T_54667">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54667_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_54667_level0_col1" class="col_heading level0 col1" >GD with L1</th>
#       <th id="T_54667_level0_col2" class="col_heading level0 col2" >GD with L2</th>
#       <th id="T_54667_level0_col3" class="col_heading level0 col3" >GD with both</th>
#       <th id="T_54667_level0_col4" class="col_heading level0 col4" >GD without regularization</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54667_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54667_row0_col0" class="data row0 col0" >Hours_Studied</td>
#       <td id="T_54667_row0_col1" class="data row0 col1" >1.745742</td>
#       <td id="T_54667_row0_col2" class="data row0 col2" >1.724936</td>
#       <td id="T_54667_row0_col3" class="data row0 col3" >1.742076</td>
#       <td id="T_54667_row0_col4" class="data row0 col4" >1.752640</td>
#     </tr>
#     <tr>
#       <th id="T_54667_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_54667_row1_col0" class="data row1 col0" >Attendance</td>
#       <td id="T_54667_row1_col1" class="data row1 col1" >2.321972</td>
#       <td id="T_54667_row1_col2" class="data row1 col2" >2.318954</td>
#       <td id="T_54667_row1_col3" class="data row1 col3" >2.315760</td>
#       <td id="T_54667_row1_col4" class="data row1 col4" >2.315526</td>
#     </tr>
#     <tr>
#       <th id="T_54667_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_54667_row2_col0" class="data row2 col0" >Sleep_Hours</td>
#       <td id="T_54667_row2_col1" class="data row2 col1" >0.021022</td>
#       <td id="T_54667_row2_col2" class="data row2 col2" >0.007106</td>
#       <td id="T_54667_row2_col3" class="data row2 col3" >0.016925</td>
#       <td id="T_54667_row2_col4" class="data row2 col4" >-0.003945</td>
#     </tr>
#     <tr>
#       <th id="T_54667_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_54667_row3_col0" class="data row3 col0" >Previous_Scores</td>
#       <td id="T_54667_row3_col1" class="data row3 col1" >0.689996</td>
#       <td id="T_54667_row3_col2" class="data row3 col2" >0.685609</td>
#       <td id="T_54667_row3_col3" class="data row3 col3" >0.670715</td>
#       <td id="T_54667_row3_col4" class="data row3 col4" >0.686722</td>
#     </tr>
#     <tr>
#       <th id="T_54667_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_54667_row4_col0" class="data row4 col0" >Tutoring_Sessions</td>
#       <td id="T_54667_row4_col1" class="data row4 col1" >0.607041</td>
#       <td id="T_54667_row4_col2" class="data row4 col2" >0.614647</td>
#       <td id="T_54667_row4_col3" class="data row4 col3" >0.603161</td>
#       <td id="T_54667_row4_col4" class="data row4 col4" >0.579316</td>
#     </tr>
#     <tr>
#       <th id="T_54667_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_54667_row5_col0" class="data row5 col0" >Physical_Activity</td>
#       <td id="T_54667_row5_col1" class="data row5 col1" >0.214949</td>
#       <td id="T_54667_row5_col2" class="data row5 col2" >0.206981</td>
#       <td id="T_54667_row5_col3" class="data row5 col3" >0.196648</td>
#       <td id="T_54667_row5_col4" class="data row5 col4" >0.186997</td>
#     </tr>
#     <tr>
#       <th id="T_54667_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_54667_row6_col0" class="data row6 col0" >Parental_Involvement - Low</td>
#       <td id="T_54667_row6_col1" class="data row6 col1" >4.461052</td>
#       <td id="T_54667_row6_col2" class="data row6 col2" >4.541810</td>
#       <td id="T_

# %% [markdown]
# #### Closed form weights

# %%
models = [closed_form_LR_L2, closed_form_LR]
model_names = ['CF with L2', 'CF without regularization']

df_weights_reg = weights_table(data, X, models, model_names)

display(df_weights_reg)
# Out:
# <style type="text/css">
# #T_f6a8d th {
#   text-align: left;
# }
# #T_f6a8d_row0_col0, #T_f6a8d_row0_col1, #T_f6a8d_row0_col2, #T_f6a8d_row1_col0, #T_f6a8d_row1_col1, #T_f6a8d_row1_col2, #T_f6a8d_row2_col0, #T_f6a8d_row2_col1, #T_f6a8d_row2_col2, #T_f6a8d_row3_col0, #T_f6a8d_row3_col1, #T_f6a8d_row3_col2, #T_f6a8d_row4_col0, #T_f6a8d_row4_col1, #T_f6a8d_row4_col2, #T_f6a8d_row5_col0, #T_f6a8d_row5_col1, #T_f6a8d_row5_col2, #T_f6a8d_row6_col0, #T_f6a8d_row6_col1, #T_f6a8d_row6_col2, #T_f6a8d_row7_col0, #T_f6a8d_row7_col1, #T_f6a8d_row7_col2, #T_f6a8d_row8_col0, #T_f6a8d_row8_col1, #T_f6a8d_row8_col2, #T_f6a8d_row9_col0, #T_f6a8d_row9_col1, #T_f6a8d_row9_col2, #T_f6a8d_row10_col0, #T_f6a8d_row10_col1, #T_f6a8d_row10_col2, #T_f6a8d_row11_col0, #T_f6a8d_row11_col1, #T_f6a8d_row11_col2, #T_f6a8d_row12_col0, #T_f6a8d_row12_col1, #T_f6a8d_row12_col2, #T_f6a8d_row13_col0, #T_f6a8d_row13_col1, #T_f6a8d_row13_col2, #T_f6a8d_row14_col0, #T_f6a8d_row14_col1, #T_f6a8d_row14_col2, #T_f6a8d_row15_col0, #T_f6a8d_row15_col1, #T_f6a8d_row15_col2, #T_f6a8d_row16_col0, #T_f6a8d_row16_col1, #T_f6a8d_row16_col2, #T_f6a8d_row17_col0, #T_f6a8d_row17_col1, #T_f6a8d_row17_col2, #T_f6a8d_row18_col0, #T_f6a8d_row18_col1, #T_f6a8d_row18_col2, #T_f6a8d_row19_col0, #T_f6a8d_row19_col1, #T_f6a8d_row19_col2, #T_f6a8d_row20_col0, #T_f6a8d_row20_col1, #T_f6a8d_row20_col2, #T_f6a8d_row21_col0, #T_f6a8d_row21_col1, #T_f6a8d_row21_col2, #T_f6a8d_row22_col0, #T_f6a8d_row22_col1, #T_f6a8d_row22_col2, #T_f6a8d_row23_col0, #T_f6a8d_row23_col1, #T_f6a8d_row23_col2, #T_f6a8d_row24_col0, #T_f6a8d_row24_col1, #T_f6a8d_row24_col2, #T_f6a8d_row25_col0, #T_f6a8d_row25_col1, #T_f6a8d_row25_col2, #T_f6a8d_row26_col0, #T_f6a8d_row26_col1, #T_f6a8d_row26_col2, #T_f6a8d_row27_col0, #T_f6a8d_row27_col1, #T_f6a8d_row27_col2, #T_f6a8d_row28_col0, #T_f6a8d_row28_col1, #T_f6a8d_row28_col2, #T_f6a8d_row29_col0, #T_f6a8d_row29_col1, #T_f6a8d_row29_col2, #T_f6a8d_row30_col0, #T_f6a8d_row30_col1, #T_f6a8d_row30_col2, #T_f6a8d_row31_col0, #T_f6a8d_row31_col1, #T_f6a8d_row31_col2, #T_f6a8d_row32_col0, #T_f6a8d_row32_col1, #T_f6a8d_row32_col2, #T_f6a8d_row33_col0, #T_f6a8d_row33_col1, #T_f6a8d_row33_col2, #T_f6a8d_row34_col0, #T_f6a8d_row34_col1, #T_f6a8d_row34_col2, #T_f6a8d_row35_col0, #T_f6a8d_row35_col1, #T_f6a8d_row35_col2, #T_f6a8d_row36_col0, #T_f6a8d_row36_col1, #T_f6a8d_row36_col2, #T_f6a8d_row37_col0, #T_f6a8d_row37_col1, #T_f6a8d_row37_col2, #T_f6a8d_row38_col0, #T_f6a8d_row38_col1, #T_f6a8d_row38_col2, #T_f6a8d_row39_col0, #T_f6a8d_row39_col1, #T_f6a8d_row39_col2, #T_f6a8d_row40_col0, #T_f6a8d_row40_col1, #T_f6a8d_row40_col2 {
#   text-align: left;
#   white-space: normal;
#   min-width: 200px;
# }
# </style>
# <table id="T_f6a8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6a8d_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_f6a8d_level0_col1" class="col_heading level0 col1" >CF with L2</th>
#       <th id="T_f6a8d_level0_col2" class="col_heading level0 col2" >CF without regularization</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6a8d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6a8d_row0_col0" class="data row0 col0" >Hours_Studied</td>
#       <td id="T_f6a8d_row0_col1" class="data row0 col1" >1.737367</td>
#       <td id="T_f6a8d_row0_col2" class="data row0 col2" >1.741574</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f6a8d_row1_col0" class="data row1 col0" >Attendance</td>
#       <td id="T_f6a8d_row1_col1" class="data row1 col1" >2.312320</td>
#       <td id="T_f6a8d_row1_col2" class="data row1 col2" >2.316914</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f6a8d_row2_col0" class="data row2 col0" >Sleep_Hours</td>
#       <td id="T_f6a8d_row2_col1" class="data row2 col1" >0.013890</td>
#       <td id="T_f6a8d_row2_col2" class="data row2 col2" >0.014101</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f6a8d_row3_col0" class="data row3 col0" >Previous_Scores</td>
#       <td id="T_f6a8d_row3_col1" class="data row3 col1" >0.695239</td>
#       <td id="T_f6a8d_row3_col2" class="data row3 col2" >0.696057</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f6a8d_row4_col0" class="data row4 col0" >Tutoring_Sessions</td>
#       <td id="T_f6a8d_row4_col1" class="data row4 col1" >0.607559</td>
#       <td id="T_f6a8d_row4_col2" class="data row4 col2" >0.608009</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f6a8d_row5_col0" class="data row5 col0" >Physical_Activity</td>
#       <td id="T_f6a8d_row5_col1" class="data row5 col1" >0.194437</td>
#       <td id="T_f6a8d_row5_col2" class="data row5 col2" >0.194955</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f6a8d_row6_col0" class="data row6 col0" >Parental_Involvement - Low</td>
#       <td id="T_f6a8d_row6_col1" class="data row6 col1" >4.569217</td>
#       <td id="T_f6a8d_row6_col2" class="data row6 col2" >4.584996</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f6a8d_row7_col0" class="data row7 col0" >Parental_Involvement - Medium</td>
#       <td id="T_f6a8d_row7_col1" class="data row7 col1" >2.623195</td>
#       <td id="T_f6a8d_row7_col2" class="data row7 col2" >2.633094</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f6a8d_row8_col0" class="data row8 col0" >Parental_Involvement - High</td>
#       <td id="T_f6a8d_row8_col1" class="data row8 col1" >3.524392</td>
#       <td id="T_f6a8d_row8_col2" class="data row8 col2" >3.522871</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f6a8d_row9_col0" class="data row9 col0" >Access_to_Resources - High</td>
#       <td id="T_f6a8d_row9_col1" class="data row9 col1" >4.580966</td>
#       <td id="T_f6a8d_row9_col2" class="data row9 col2" >4.595785</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f6a8d_row10_col0" class="data row10 col0" >Access_to_Resources - Medium</td>
#       <td id="T_f6a8d_row10_col1" class="data row10 col1" >2.532252</td>
#       <td id="T_f6a8d_row10_col2" class="data row10 col2" >2.542206</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f6a8d_row11_col0" class="data row11 col0" >Access_to_Resources - Low</td>
#       <td id="T_f6a8d_row11_col1" class="data row11 col1" >3.603586</td>
#       <td id="T_f6a8d_row11_col2" class="data row11 col2" >3.602970</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f6a8d_row12_col0" class="data row12 col0" >Extracurricular_Activities - No</td>
#       <td id="T_f6a8d_row12_col1" class="data row12 col1" >5.093498</td>
#       <td id="T_f6a8d_row12_col2" class="data row12 col2" >5.109045</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f6a8d_row13_col0" class="data row13 col0" >Extracurricular_Activities - Yes</td>
#       <td id="T_f6a8d_row13_col1" class="data row13 col1" >5.623306</td>
#       <td id="T_f6a8d_row13_col2" class="data row13 col2" >5.631916</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f6a8d_row14_col0" class="data row14 col0" >Motivation_Level - Low</td>
#       <td id="T_f6a8d_row14_col1" class="data row14 col1" >4.083082</td>
#       <td id="T_f6a8d_row14_col2" class="data row14 col2" >4.108479</td>
#     </tr>
#     <tr>
#       <th id="T_f6a8d_level0_row15" class="row_heading level0 row

# %% [markdown]
# #### Cross-validation

# %%
from sklearn.model_selection import cross_validate, KFold

kfold = KFold(n_splits=3, shuffle=True, random_state=42)

GD_L1_cross_val = cross_validate(gd_LR_L1_pipeline, X_train, Y_train, cv=kfold,
                              scoring=('r2', 'neg_mean_squared_error', 'neg_mean_absolute_error'),
                              return_train_score=True)

GD_L2_cross_val = cross_validate(gd_LR_L2_pipeline, X_train, Y_train, cv=kfold,
                              scoring=('r2', 'neg_mean_squared_error', 'neg_mean_absolute_error'),
                              return_train_score=True)

GD_en_cross_val = cross_validate(gd_LR_en_pipeline, X_train, Y_train, cv=kfold,
                              scoring=('r2', 'neg_mean_squared_error', 'neg_mean_absolute_error'),
                              return_train_score=True)

GD_cross_val = cross_validate(gradient_descent_pipeline, X_train, Y_train, cv=kfold,
                              scoring=('r2', 'neg_mean_squared_error', 'neg_mean_absolute_error'),
                              return_train_score=True)

CF_L2_cross_val = cross_validate(cf_LR_L2_pipeline, X_train, Y_train, cv=kfold,
                              scoring=('r2', 'neg_mean_squared_error', 'neg_mean_absolute_error'),
                              return_train_score=True)

CF_cross_val = cross_validate(closed_form_pipeline, X_train, Y_train, cv=kfold,
                              scoring=('r2', 'neg_mean_squared_error', 'neg_mean_absolute_error'),
                              return_train_score=True)

# %%
import numpy as np

model_names = [ 'Closed Form with L2',
                'Closed for without regularization',
                'Gradient Descent with L1',
                'Gradient Descent with L2',
                'Gradient Descent with both (0.5 ratio)',
                'Gradient Descent without regularization']
cross_vals = [CF_L2_cross_val, CF_cross_val, GD_L1_cross_val, GD_L2_cross_val, GD_en_cross_val, GD_cross_val]
metrics = ['R² (test)', 'R² (train)', 'R² difference', 'MSE (test)', 'MAE (test)']

results = {
    name: [
        np.mean(cross_val['test_r2']),
        np.mean(cross_val['train_r2']),
        np.mean(cross_val['train_r2']) - np.mean(cross_val['test_r2']),
        -np.mean(cross_val['test_neg_mean_squared_error']),
        -np.mean(cross_val['test_neg_mean_absolute_error'])
    ]
    for (name, cross_val) in zip(model_names, cross_vals) 
}

df_cross_val = pd.DataFrame(results, index=metrics).T.round(6)

display(df_cross_val)
# Out:
#                                          R² (test)  R² (train)  R² difference  \
# Closed Form with L2                       0.708449    0.711722       0.003273
# Closed for without regularization         0.708800    0.712169       0.003370
# Gradient Descent with L1                  0.708554    0.711767       0.003213
# Gradient Descent with L2                  0.708254    0.711763       0.003509
# Gradient Descent with both (0.5 ratio)    0.708442    0.711679       0.003237
# Gradient Descent without regularization   0.708564    0.711941       0.003378
#
#                                          MSE (test)  MAE (test)
# Closed Form with L2                        4.496935    0.495147
# Closed for without regularization          4.491366    0.509652
# Gradient Descent with L1                   4.495075    0.493478
# Gradient Descent with L2                   4.499794    0.524779
# Gradient Descent with both (0.5 ratio)     4.497040    0.520927
# Gradient Descent without regularization    4.494927    0.519217
